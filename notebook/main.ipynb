# %% [markdown]
# # **Strum AI**
#
# StrumAI is an AI-powered tool that listens to short guitar audio clips and predicts the chords (or tabs) being played. The goal is to help musicians, learners, and creators identify and play along with chords using intelligent machine learning and deep learning models.

# %%
# !pip install librosa numpy matplotlib jams
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting librosa
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: numpy in c:\users\revna\appdata\roaming\python\python312\site-packages (2.3.1)
# Requirement already satisfied: matplotlib in c:\users\revna\appdata\roaming\python\python312\site-packages (3.10.0)
# Collecting jams
#   Using cached jams-0.3.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numba>=0.51.0 (from librosa)
#   Using cached numba-0.61.2-cp312-cp312-win_amd64.whl.metadata (2.9 kB)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from librosa) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from librosa) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from librosa) (0.13.1)
# Collecting pooch>=1.1 (from librosa)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Using cached soxr-0.5.0.post1-cp312-abi3-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from librosa) (0.4)
# Collecting msgpack>=1.0 (from librosa)
#   Using cached msgpack-1.1.1-cp312-cp312-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\revna\appdata\roaming\python\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\revna\appdata\roaming\python\python312\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\revna\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: jsonschema>=4.0.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from jams) (4.23.0)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from jams) (2.3.1)
# Collecting mir_eval>=0.8.2 (from jams)
#   Using cached mir_eval-0.8.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sortedcontainers>=2.1.0 (from jams)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six in c:\users\revna\appdata\roaming\python\python312\site-packages (from jams) (1.17.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from jsonschema>=4.0.1->jams) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\revna\appdata\roaming\python\python312\site-packages (from jsonschema>=4.0.1->jams) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\revna\appdata\roaming\python\python312\site-packages (from jsonschema>=4.0.1->jams) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from jsonschema>=4.0.1->jams) (0.22.3)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.51.0->librosa)
#   Using cached llvmlite-0.44.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting numpy
#   Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from pandas>=1.2.0->jams) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\revna\appdata\roaming\python\python312\site-packages (from pandas>=1.2.0->jams) (2025.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\revna\appdata\roaming\python\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\revna\appdata\roaming\python\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\revna\appdata\roaming\python\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\revna\appdata\roaming\python\python312\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.12.14)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from scikit-learn>=1.1.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\revna\appdata\roaming\python\python312\site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\revna\appdata\roaming\python\python312\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Using cached librosa-0.11.0-py3-none-any.whl (260 kB)
# Using cached jams-0.3.5-py3-none-any.whl (67 kB)
# Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# Using cached mir_eval-0.8.2-py3-none-any.whl (102 kB)
# Using cached msgpack-1.1.1-cp312-cp312-win_amd64.whl (72 kB)
# Using cached numba-0.61.2-cp312-cp312-win_amd64.whl (2.8 MB)
# Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached llvmlite-0.44.0-cp312-cp312-win_amd64.whl (30.3 MB)
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached soxr-0.5.0.post1-cp312-abi3-win_amd64.whl (164 kB)
# Installing collected packages: sortedcontainers, numpy, msgpack, llvmlite, audioread, soxr, pooch, numba, mir_eval, librosa, jams
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.3.1
#
#    --- ------------------------------------  1/11 [numpy]
#     Uninstalling numpy-2.3.1:
#    --- ------------------------------------  1/11 [numpy]
#       Successfully uninstalled numpy-2.3.1
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    --- ------------------------------------  1/11 [numpy]
#    ---------- -----------------------------  3/11 [llvmlite]
#    ---------- -----------------------------  3/11 [llvmlite]
#    ---------- -----------------------------  3/11 [llvmlite]
#    ---------- -----------------------------  3/11 [llvmlite]
#    ---------- -----------------------------  3/11 [llvmlite]
#    -------------- -------------------------  4/11 [audioread]
#    --------------------- ------------------  6/11 [pooch]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ------------------------- --------------  7/11 [numba]
#    ----------------------------- ----------  8/11 [mir_eval]
#    -------------------------------- -------  9/11 [librosa]
#    ------------------------------------ --- 10/11 [jams]
#    ---------------------------------------- 11/11 [jams]
#
# Successfully installed audioread-3.0.1 jams-0.3.5 librosa-0.11.0 llvmlite-0.44.0 mir_eval-0.8.2 msgpack-1.1.1 numba-0.61.2 numpy-2.2.6 pooch-1.8.2 sortedcontainers-2.4.0 soxr-0.5.0.post1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chromadb 0.5.23 requires tokenizers<=0.20.3,>=0.13.2, but you have tokenizers 0.21.0 which is incompatible.
# langchain-chroma 0.2.0 requires numpy<2.0.0,>=1.26.2; python_version >= "3.12", but you have numpy 2.2.6 which is incompatible.
# tensorflow-intel 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.

# %%
import os
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import jams

# %%
print("Librosa version:", librosa.__version__)
print("JAMS version:", jams.__version__)
# Out:
# Librosa version: 0.11.0
# JAMS version: 0.3.5

# %% [markdown]
# **Load a .wav file**

# %%
# Path to one audio file
wav_path = "../Data/audio_hex-pickup_original/00_BN1-129-Eb_solo_hex.wav"

# Load audio (default SR = 22050 Hz)
y, sr = librosa.load(wav_path)

print(f"Audio shape: {y.shape}, Sample rate: {sr}")
# Out:
# Audio shape: (492253,), Sample rate: 22050
